# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - Extract API Data

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# *   Collect exchange rate data using an API
# *   Store the data as a CSV

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
# !mamba install pandas==1.3.3 -y
# !mamba install requests==2.26.0 -y
# Out:
# 'mamba' is not recognized as an internal or external command,
# operable program or batch file.
# 'mamba' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Extract Data Using an API

# %% [markdown]
# Using ExchangeRate-API we will extract currency exchange rate data. Use the below steps to get the access key and to get the data.
#
# 1.  Open the url : [https://exchangeratesapi.io/](https://exchangeratesapi.io/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) and click on **Get Free API Key**.
# 2.  Subscribe for Free plan and Sign-in with the Google Account.
# 3.  Once the account is created you will be redirected to [https://apilayer.com](https://apilayer.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) website.
# 4.  Now, click on the **user icon** and click **Account** as shown below:
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/Images/account.png"/>
#
# 3.  Scroll down and you will get the API Key section. Copy the API key and use in the url in Question 1.

# %% [markdown]
# ### Call the API
#
# <b> Question 1</b> Using the `requests` library call the endpoint given above and save the text, remember the first few characters of the output:

# %%
url = "https://api.apilayer.com/exchangerates_data/latest?base=EUR&apikey=jp41rBLL6lKB4EzHv2Dd4XEwjRYCxuz7"
response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'success': True, 'timestamp': 1658097004, 'base': 'EUR', 'date': '2022-07-17', 'rates': {'AED': 3.70263, 'AFN': 88.558726, 'ALL': 117.064411, 'AMD': 416.259032, 'ANG': 1.813798, 'AOA': 435.393914, 'ARS': 128.760848, 'AUD': 1.484774, 'AWG': 1.811978, 'AZN': 1.712978, 'BAM': 1.956907, 'BBD': 2.032118, 'BDT': 94.554425, 'BGN': 1.956536, 'BHD': 0.380509, 'BIF': 2071.970028, 'BMD': 1.008055, 'BND': 1.411477, 'BOB': 6.919207, 'BRL': 5.453473, 'BSD': 1.006454, 'BTC': 4.8047928e-05, 'BTN': 80.335102, 'BWP': 12.88649, 'BYN': 2.54008, 'BYR': 19757.871063, 'BZD': 2.028716, 'CAD': 1.312639, 'CDF': 2018.630688, 'CHF': 0.984678, 'CLF': 0.038387, 'CLP': 1059.213189, 'CNY': 6.811829, 'COP': 4520.887457, 'CRC': 687.378205, 'CUC': 1.008055, 'CUP': 26.713448, 'CVE': 110.325703, 'CZK': 24.522741, 'DJF': 179.168581, 'DKK': 7.44281, 'DOP': 54.941229, 'DZD': 148.546733, 'EGP': 19.047899, 'ERN': 15.12082, 'ETB': 52.530303, 'EUR': 1, 'FJD': 2.248214, 'FKP': 0.849122, 'GBP': 0.849609, 'GEL': 2.964215, 'GGP': 0.849122, 'GHS': 8.177299, 'GIP': 0.849122, 'GMD': 54.525504, 'GNF': 8730.303538, 'GTQ': 7.789786, 'GYD': 210.565856, 'HKD': 7.913053, 'HNL': 24.742614, 'HRK': 7.503554, 'HTG': 116.623168, 'HUF': 401.029364, 'IDR': 15117.140292, 'ILS': 3.492476, 'IMP': 0.849122, 'INR': 80.428143, 'IQD': 1468.888203, 'IRR': 42691.114193, 'ISK': 138.829394, 'JEP': 0.849122, 'JMD': 152.681007, 'JOD': 0.714726, 'JPY': 139.557607, 'KES': 119.161765, 'KGS': 81.621583, 'KHR': 4111.262075, 'KMF': 468.367411, 'KPW': 907.249173, 'KRW': 1329.623998, 'KWD': 0.310484, 'KYD': 0.838761, 'KZT': 485.15694, 'LAK': 15130.224866, 'LBP': 1521.737282, 'LKR': 362.316352, 'LRD': 153.728106, 'LSL': 15.967517, 'LTL': 2.976523, 'LVL': 0.609762, 'LYD': 4.904899, 'MAD': 10.50588, 'MDL': 19.444299, 'MGA': 4237.591583, 'MKD': 61.64892, 'MMK': 1863.412176, 'MNT': 3169.989115, 'MOP': 8.137477, 'MRO': 359.875335, 'MUR': 45.575076, 'MVR': 15.473792, 'MWK': 1033.009377, 'MXN': 20.692877, 'MYR': 4.484858, 'MZN': 64.34392, 'NAD': 15.967316, 'NGN': 418.748372, 'NIO': 36.085855, 'NOK': 10.26366, 'NPR': 128.535722, 'NZD': 1.638139, 'OMR': 0.388664, 'PAB': 1.006454, 'PEN': 3.930563, 'PGK': 3.591876, 'PHP': 56.743664, 'PKR': 212.105904, 'PLN': 4.776415, 'PYG': 6903.998679, 'QAR': 3.670304, 'RON': 4.939851, 'RSD': 117.389589, 'RUB': 112.142097, 'RWF': 1038.091173, 'SAR': 3.785343, 'SBD': 8.225694, 'SCR': 13.275304, 'SDG': 460.178727, 'SEK': 10.570633, 'SGD': 1.41104, 'SHP': 1.388491, 'SLL': 13276.079749, 'SOS': 589.211494, 'SRD': 22.688788, 'STD': 20864.695919, 'SVC': 8.806846, 'SYP': 2532.766968, 'SZL': 17.291014, 'THB': 36.93005, 'TJS': 10.366304, 'TMT': 3.538272, 'TND': 3.088179, 'TOP': 2.384099, 'TRY': 17.524944, 'TTD': 6.836061, 'TWD': 30.165056, 'TZS': 2347.001354, 'UAH': 29.738563, 'UGX': 3794.287671, 'USD': 1.008055, 'UYU': 41.354754, 'UZS': 11020.743771, 'VND': 23643.921724, 'VUV': 119.85369, 'WST': 2.742887, 'XAF': 656.318116, 'XAG': 0.053846, 'XAU': 0.00059, 'XCD': 2.724318, 'XDR': 0.769724, 'XOF': 656.318116, 'XPF': 114.061739, 'YER': 252.265543, 'ZAR': 17.219509, 'ZMK': 9073.700353, 'ZMW': 16.530695, 'ZWL': 324.593185}}

# %% [markdown]
# ### Save as DataFrame
#
# <b> Question 2</b>  Using the data gathered turn it into a `pandas` dataframe. The dataframe should have the Currency as the index and `Rate` as their columns. Make sure to drop unnecessary columns.

# %%
from locale import currency


df = pd.DataFrame(data, index=data.slice(currency, 0, 100, 2), columns=[Rate])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\achar\OneDrive\Documents\GitHub\Extracting-Data-using-API\API_Engineer_Peer_Review_Assignment_Extract.ipynb Cell 14 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/achar/OneDrive/Documents/GitHub/Extracting-Data-using-API/API_Engineer_Peer_Review_Assignment_Extract.ipynb#ch0000013?line=0'>1</a> from locale import currency
# ----> <a href='vscode-notebook-cell:/c%3A/Users/achar/OneDrive/Documents/GitHub/Extracting-Data-using-API/API_Engineer_Peer_Review_Assignment_Extract.ipynb#ch0000013?line=3'>4</a> df = pd.DataFrame(data, index=data.slice(currency, 0, 100, 2), columns=[Rate])
#
# AttributeError: 'dict' object has no attribute 'slice'

# %%
df = df.drop(['USDEUR', 'EURUSD'], axis=0)

# %% [markdown]
# ### Load the Data
#
# Using the dataframe save it as a CSV names `exchange_rates_1.csv`.

# %%
# Save the Dataframe

# %% [markdown]
# Your CSV should be in this format with more currencies
#
# |     | Rates      |
# | --- | ---------- |
# | AED | 4.398618   |
# | AFN | 92.917693  |
# | ALL | 123.099093 |
# | AMD | 621.935674 |
# | ANG | 2.149648   |

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                              |
# | ----------------- | ------- | ----------------- | ----------------------------------------------- |
# | 2022-05-06        | 0.3     | Malika            | Updated instructions to get the API and the url |
# | 2021-04-15        | 0.2     | Malika            | Updated the lab from USD to EUR                 |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab              |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
